# %% [markdown]
# # Number system

# %% [markdown]
# # Decimal to binary

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(50)
# Out:
# '0b110010'

# %%
bin(85)
# Out:
# '0b1010101'

# %%
bin(65)
# Out:
# '0b1000001'

# %% [markdown]
# # Binary to decimal

# %%
int('1001010',2)
# Out:
# 74

# %%
int('1010101',2)
# Out:
# 85

# %%
int('111011011',2)
# Out:
# 475

# %%
int('110011001',2)
# Out:
# 409

# %%
int('10110011101',2)
# Out:
# 1437

# %%
int('111011',2)
# Out:
# 59

# %% [markdown]
# # Decimal to octal

# %%
oct(36)
# Out:
# '0o44'

# %%
oct(66)
# Out:
# '0o102'

# %%
oct(76)
# Out:
# '0o114'

# %%
oct(86)
# Out:
# '0o126'

# %% [markdown]
# # Octal to decimal

# %%
int('0125',8)
# Out:
# 85

# %%
int('1125',8)
# Out:
# 597

# %%
int('12222',8)
# Out:
# 5266

# %%
int('14221',8)
# Out:
# 6289

# %% [markdown]
# # Decimal to Hexa

# %%
hex(66)
# Out:
# '0x42'

# %%
hex(36)
# Out:
# '0x24'

# %%
hex(85)
# Out:
# '0x55'

# %%
hex(226)
# Out:
# '0xe2'

# %%
hex(8555)
# Out:
# '0x216b'

# %% [markdown]
# # Hexa to decimal

# %%
int('215b',16)
# Out:
# 8539

# %%
int('1224c',16)
# Out:
# 74316

# %%
int('22114',16)
# Out:
# 139540
