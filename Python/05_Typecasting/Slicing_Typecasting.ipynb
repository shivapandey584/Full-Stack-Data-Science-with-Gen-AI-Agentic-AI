# %%
s= "naresh it"
s
# Out:
# 'naresh it'

# %%
s1= wel come from nareshit 
under faculty under prakash 
senapati sir
# Out:
#   Cell In[6], line 1
#     s1= wel come from nareshit
#             ^
# SyntaxError: invalid syntax

# %%
s2= 'wel come from nareshit 
under faculty under prakash 
senapati sir '
# Out:
#   Cell In[7], line 1
#     s2= 'wel come from nareshit
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s3= "wel come from nareshit 
under faculty under prakash 
senapati sir "
# Out:
#   Cell In[8], line 1
#     s3= "wel come from nareshit
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4='''wel come from nareshit 
under faculty under prakash 
senapati sir'''
s4
# Out:
# 'wel come from nareshit \nunder faculty under prakash \nsenapati sir'

# %%
s
# Out:
# 'naresh it'

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s[:]
# Out:
# 'naresh it'

# %%
s[4]
# Out:
# 's'

# %%
s[5]
# Out:
# 'h'

# %%
s[6]
# Out:
# ' '

# %%
s[2]
# Out:
# 'r'

# %%
s[1]
# Out:
# 'a'

# %%
s[0]
# Out:
# 'n'

# %%
s[3]
# Out:
# 'e'

# %%
s[7]
# Out:
# 'i'

# %%
s[8]
# Out:
# 't'

# %%
s[:]
# Out:
# 'naresh it'

# %%
s[:5]
# Out:
# 'nares'

# %%
s[0:8:3]
# Out:
# 'ne '

# %%
s[4:5]
# Out:
# 's'

# %%
s[0:5]
# Out:
# 'nares'

# %% [markdown]
# ## backword slicing

# %%
s8= "forword"
s8
# Out:
# 'forword'

# %%
s8[-1]
# Out:
# 'd'

# %%
s8[-2]
# Out:
# 'r'

# %%
s8[-3]
# Out:
# 'o'

# %%
s8[-4]
# Out:
# 'w'

# %%
s8[-5]
# Out:
# 'r'

# %%
s8[-6]
# Out:
# 'o'

# %%
s8[-7]
# Out:
# 'f'

# %%
s8[-20] ## string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s8[-20] ## string index out of range
#
# IndexError: string index out of range

# %% [raw]
# ## Forward indexing & backword indexing & indexing error

# %%
F= "Shiva pandey"
F
# Out:
# 'Shiva pandey'

# %%
F[:]
# Out:
# 'Shiva pandey'

# %%
F[1:5]
# Out:
# 'hiva'

# %%
F[2:5]
# Out:
# 'iva'

# %%
F[2:8]
# Out:
# 'iva pa'

# %%
F[3:100]
# Out:
# 'va pandey'

# %%
F[10]
# Out:
# 'e'

# %%
F[11]
# Out:
# 'y'

# %%
F[0:11:2] ##step slicing
# Out:
# 'Siapne'

# %%
F[0:11:3]
# Out:
# 'Svpd'

# %%
F[1:6:4]
# Out:
# 'h '

# %%
F[-5:-2]
# Out:
# 'and'

# %%
F[-9:-8]
# Out:
# 'v'

# %%
F[-1:-9] ##start should be less than stop
# Out:
# ''

# %%
F[-2:-11]
# Out:
# ''

# %%
F[-9:-5:-2] ##start should be greater than stop in negative step
# Out:
# ''

# %%
F[-8:-4:3]
# Out:
# 'aa'

# %%
F[-7:2:4]
# Out:
# ''

# %% [markdown]
# ## Python type casting

# %% [markdown]
# ## All other data type to integer

# %% [raw]
# ### Float to integer

# %%
78.25
# Out:
# 78.25

# %%
int(78.25) ## we can convert float into integer
# Out:
# 78

# %%
114.8
# Out:
# 114.8

# %%
int(114.8)
# Out:
# 114

# %% [raw]
# ### Boolean to integer

# %%
int(True)  ## bool to integer possible
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(a+bj ## Complex to int not possile
# Out:
#   Cell In[29], line 1
#     int(a+bj ## Complex to int not possile
#                                           ^
# _IncompleteInputError: incomplete input

# %%
int("25") ## Numric string to integer possible
# Out:
# 25

# %%
int("shiva") ## string to int possible accept text String
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 int("shiva") ## string to int possible accept text integer
#
# ValueError: invalid literal for int() with base 10: 'shiva'

# %% [markdown]
# # Other data type float

# %%
float(45)
# Out:
# 45.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(8+8j)## complex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 float(8+8j)## complex
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float("850")## numric string
# Out:
# 850.0

# %%
float("pandey")## text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 float("pandey")## text string
#
# ValueError: could not convert string to float: 'pandey'

# %% [markdown]
# # Other data type boolean

# %%
bool(25)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(77.26)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(1+5j)
# Out:
# True

# %%
bool('88')
# Out:
# True

# %%
bool("naresh")
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool("_")
# Out:
# True

# %% [markdown]
# # Other data type complex

# %%
complex(5)
# Out:
# (5+0j)

# %%
complex(5,8)
# Out:
# (5+8j)

# %%
complex(88)
# Out:
# (88+0j)

# %%
complex(1.9)
# Out:
# (1.9+0j)

# %%
complex(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 complex(1,2,3)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(45,55)
# Out:
# (45+55j)

# %%
complex(2.1,5.2)
# Out:
# (2.1+5.2j)

# %%
complex(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 complex(true)
#
# NameError: name 'true' is not defined

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex("98")
# Out:
# (98+0j)

# %%
complex("science")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 complex("science")
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# # Other data type string

# %%
str(110)
# Out:
# '110'

# %%
str(888)
# Out:
# '888'

# %%
str(110.01)
# Out:
# '110.01'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(4+9j)
# Out:
# '(4+9j)'

# %%
d1= "programming"
d1
# Out:
# 'programming'

# %% [markdown]
# d1[:]

# %%
d1(8:2:-1)
# Out:
#   Cell In[80], line 1
#     d1(8:2:-1)
#         ^
# SyntaxError: invalid syntax

# %%
s1="shiva"
s1
# Out:
# 'shiva'

# %%
s1[4:2:-1]
# Out:
# 'av'

# %%
s1[5:2:-5]
# Out:
# 'a'

# %%
s1
