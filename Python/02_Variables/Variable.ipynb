# %% [markdown]
# # Variable

# %% [markdown]
# ### Syntax: variable_name = Value

# %%
p = 8
p
# Out:
# 8

# %%
a1 = 8
a1
# Out:
# 8

# %%
name = 'arush'
name
# Out:
# 'arush'

# %% [markdown]
# # Rules For Variables

# %% [markdown]
# ### 1.Variable does not start with Number But Ends With Number

# %%
1a =74
1a
# Out:
#   Cell In[8], line 1
#     1a =74
#     ^
# SyntaxError: invalid decimal literal

# %%
7abc =88
7abc
# Out:
#   Cell In[9], line 1
#     7abc =88
#     ^
# SyntaxError: invalid decimal literal

# %%
a5 = 52
a5
# Out:
# 52

# %%
rat7 = 55
rat7
# Out:
# 55

# %% [markdown]
# ### 2.Variable are Case Senstive

# %%
p =45
P = 87

# %%
p
# Out:
# 45

# %%
P
# Out:
# 87

# %%
dat3 = 78
Dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 dat3 = 78
# ----> 2 Dat
#
# NameError: name 'Dat' is not defined

# %%
a=89
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 a=89
# ----> 2 A
#
# NameError: name 'A' is not defined

# %% [markdown]
# ### 3.Special Charactar Are  Not Allowed Except Underscore(_)

# %%
name@= 'arun'
name@
# Out:
#   Cell In[38], line 2
#     name@
#          ^
# SyntaxError: invalid syntax

# %%
shop%= 87.85
shop%
# Out:
#   Cell In[22], line 2
#     shop%
#          ^
# SyntaxError: invalid syntax

# %%
american$= 99
american$
# Out:
#   Cell In[23], line 1
#     american$= 99
#             ^
# SyntaxError: invalid syntax

# %%
first_name='shiva'
first_name
# Out:
# 'shiva'

# %%
last_name='pandey'
last_name
# Out:
# 'pandey'

# %%
_age=22
_age
# Out:
# 22

# %%
_date='22/4/22'
_date
# Out:
# '22/4/22'

# %% [markdown]
# # Keywords

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [raw]
# - These are the keywords or reserved words in python.
# - Total 35 keywords in python.
