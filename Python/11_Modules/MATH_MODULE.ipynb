# %% [markdown]
# # Math module

# %% [markdown]
# The `math` module is a built-in Python module.

# %%
sqrt(35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sqrt(35)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# ## 1. Import Math Module

# %%
import math

# %% [markdown]
# ## Sqrt function

# %%
math.sqrt(35)
# Out:
# 5.916079783099616

# %%
math .sqrt(256)
# Out:
# 16.0

# %%
math.sqrt(36)
# Out:
# 6.0

# %% [markdown]
# ## Floor function

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.floor(5.8)
# Out:
# 5

# %% [markdown]
# ## Ceil function

# %%
math.ceil(4.6)
# Out:
# 5

# %%
math.ceil(9.9)
# Out:
# 10

# %%
math.ceil(9.15)
# Out:
# 10

# %% [markdown]
# ## Power function

# %%
math.pow(10,5)
# Out:
# 100000.0

# %%
math.pow(45,6)
# Out:
# 8303765625.0

# %%
math.pow(36,6)
# Out:
# 2176782336.0

# %% [markdown]
# ## import math as shiva

# %%
import math as shiva

# %%
shiva.sqrt(25)
# Out:
# 5.0

# %%
shiva.floor(36.5)
# Out:
# 36

# %%
shiva.ceil(36.5)
# Out:
# 37

# %%
shiva.pow(55,3)
# Out:
# 166375.0

# %% [markdown]
# ## From math import *
# ## to import all math  function

# %%
from math import pow, floor, ceil, sqrt ## to import specific math function

# %%
sqrt(24)
# Out:
# 4.898979485566356

# %%
floor(2.5)
# Out:
# 2

# %%
ceil(5.6)
# Out:
# 6

# %%
pow(23,3)
# Out:
# 12167.0

# %%
print(sqrt(24))
print(floor(2.5))
print(ceil(5.6))
print(pow(23,3))
# Out:
# 4.898979485566356
# 2
# 6
# 12167.0
