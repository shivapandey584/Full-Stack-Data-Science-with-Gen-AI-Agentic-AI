# %% [markdown]
# # Python print function

# %% [raw]
# ### print is use of answer

# %%
sub_= 5
sub_1=25
sub_
sub_1
# Out:
# 25

# %%
sub_= 5
sub_1=25
print(sub_)
print(sub_1)
# Out:
# 5
# 25

# %%
sub_,sub_1= 5,25
print(sub_,sub_1)
# Out:
# 5 25

# %%
print(5)
print(25)
print("data science")
print(5,25,"data science")
# Out:
# 5
# 25
# data science
# 5 25 data science

# %%
sub_=55
sub_1=50
add=sub_+sub_1
print(add)
# Out:
# 105

# %%
sub_1=5500
sub_2=6500
sub_3=7500
Total=sub_1+sub_2+sub_3
print(Total)
# Out:
# 19500

# %% [markdown]
# ## Code optimaization

# %%
sub1= 36
sub2=46
sub3=26
print(sub1)
print(sub2)
print(sub3)
# Out:
# 36
# 46
# 26

# %%
sub1= 36
sub2=46
sub3=26
print(sub1,sub2,sub3)
# Out:
# 36 46 26

# %% [markdown]
# # Print result with string

# %%
sub_1=85
sub_2=55
subtract=sub_1-sub_2
print('the substraction is',sub_1,'and',sub_2,'is=',subtract)
# Out:
# the substraction is 85 and 55 is= 30

# %%
name = 'shiva pandey'
age = 21
city= 'ayodhya'
## hello python my name is shiva pandey and i am 21 years old from ayodhya

# %%
print('my name is',name,'and i am',age,'year old from',city)
# Out:
# my name is shiva pandey and i am 21 year old from ayodhya

# %% [markdown]
# ## print format method

# %%
sub=52
sub1=88
add=sub+sub1
print('the addition of {} and {}is={}'.format(sub,sub1,add))
# Out:
# the addition of 52 and 88is=140

# %%
sub=45
sub1=55
sub2=555
add=sub+sub1+sub2
print('the addition of {}and{} and{}is={}'.format(sub,sub1,sub2,add))
# Out:
# the addition of 45and55 and555is=655

# %% [raw]
# ## first deside how the print statement should be

# %% [raw]
# ## like:- The addition of 20 and 30 is = 50

# %% [raw]
# ## Then replace the variable position with curly bracket

# %% [raw]
# ## Then apply format(sub1,sub1......sub-n)method

# %%
name="shiva pandey"
age =21
city='Ayodhya'
print(' my name is {}and i am {} year old from sity from{}'.format(name,age,city))
# Out:
#  my name is shiva pandeyand i am 21 year old from sity fromAyodhya

# %%
sub=155
sub1=255
sub2=355
avg=round((sub+sub1+sub2)/2,1)## we cane use avg=round((sub+sub1+sub2)/2,1)
## the average of sub,sub1,sub2 is =avg

# %%
print('f.the average of{sub},{sub1} and {sub2}is =avg')
# Out:
# f.the average of{sub},{sub1} and {sub2}is =avg

# %%
## combine all
sub=25
sub1=35
sub2=45
add=sub+sub1+sub2
print('the addiotion of',sub,'and',sub1,'and' ,sub2,'is =',add)
print('the addiotionn of {} and {}and{} is={}'.format(sub,sub1,sub2,add))
print('f.the average of {sub},{sub1}and{sub2}is= avg')
# Out:
# the addiotion of 25 and 35 and 45 is = 105
# the addiotionn of 25 and 35and45 is=105
# f.the average of {sub},{sub1}and{sub2}is= avg

# %% [markdown]
# ## End statement

# %%
print('Hello')
print( 'shiva pandey')
# i want to write in one line
# Out:
# Hello
# shiva pandey

# %%
print('Hello',end=' ')
print('shiva pandey')
# Out:
# Hello shiva pandey

# %%
print('my name',end=' ')
print('shiva pandey')
# Out:
# my name shiva pandey

# %%
print('I am ',end='')
print('Ayodhya')
# Out:
# I am Ayodhya

# %% [markdown]
# # Seprator

# %% [raw]
# # Here one print statemnt only we use

# %% [raw]
# #inside one print statement we have multiple values

# %% [raw]
# # we want to seperate these multiple value with anything

# %%
print('i am ','shiva','from ayodhya',sep= '====>')
# Out:
# i am ====>shiva====>from ayodhya

# %%
print('naresh it','hydrabaad',sep= '****')
# Out:
# naresh it****hydrabaad

# %%
print('full','stack','data','science',sep= '&')
# Out:
# full&stack&data&science

# %%
print(2,5, end='')
print(5,'.',sep='')
# Out:
# 2 55.
