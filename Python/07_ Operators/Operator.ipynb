# %% [markdown]
# # Operator

# %%
sub=8
sub1=5
print(sub)
print(sub1)
# Out:
# 8
# 5

# %% [markdown]
# # 1.Arithmatic operator

# %% [markdown]
# ### Arithmetic operators are used for mathematical calculations.
#
# | Operator | Name           | Example   | Result |
# | -------- | -------------- | --------- | ------ |
# | `+`      | Addition       | `10 + 5`  | `15`   |
# | `-`      | Subtraction    | `10 - 5`  | `5`    |
# | `*`      | Multiplication | `10 * 5`  | `50`   |
# | `/`      | Division       | `10 / 5`  | `2.0`  |
# | `%`      | Modulus        | `10 % 3`  | `1`    |
# | `//`     | Floor Division | `10 // 3` | `3`    |
# | `**`     | Exponent       | `2 ** 3`  | `8`    |

# %% [markdown]
# # Addition

# %%
sub1=25
sub2=35
print(sub1+sub2)
# Out:
# 60

# %% [markdown]
# # Subtraction

# %%
sub1=25
sub2=30
print(sub1-sub2)
# Out:
# -5

# %% [markdown]
# # Multiplication

# %%
sub1=95
sub2=25
print(sub1*sub2)
# Out:
# 2375

# %% [markdown]
# # Division

# %%
sub1=25 ## its gives in decimalvalue 
sub2=2
print(sub1/sub2)
# Out:
# 12.5

# %% [markdown]
# # Floor division

# %%
sub1=25 ## its gives integer value
sub2=2
print(sub1//sub2)
# Out:
# 12

# %% [markdown]
# #  Modules (For remainder)

# %%
sub1=25 ## its gives remainder
sub2=20
print(sub1%sub2)
# Out:
# 5

# %% [markdown]
# # Exponent

# %%
sub1=2
sub2=3
print(sub1**sub2)
# Out:
# 8

# %% [markdown]
# # 2.Assigement operator

# %% [markdown]
# ### Assignment operators are used to assign values to variables.
#
# | Operator | Example  | Meaning     |
# | -------- | -------- | ----------- |
# | `=`      | `x = 10` | Assign      |
# | `+=`     | `x += 5` | `x = x + 5` |
# | `-=`     | `x -= 5` | `x = x - 5` |
# | `*=`     | `x *= 5` | `x = x * 5`
# | `/=`     | `x /= 5` | `x = x / 5` |

# %%
sub=25 ## assing
print(sub)
# Out:
# 25

# %%
sub+=10
print(sub)
# Out:
# 35

# %%
sub-=35
print(sub)
# Out:
# 0

# %%
sub*=15
print(sub)
# Out:
# 0

# %%
sub/=2
print(sub)
# Out:
# 0.0

# %% [markdown]
# # 3. Relational Operators

# %% [markdown]
# ### Relational operators compare two values.
#
# The result is always **True** or **False**.
#
# | Operator | Meaning                  |
# | -------- | ------------------------ |
# | `==`     | Equal to                 |
# | `!=`     | Not equal to             |
# | `>`      | Greater than             |
# | `<`      | Less than                |
# | `>=`     | Greater than or equal to |
# | `<=`     | Less than or equal to    |

# %%
s1=85
s2=25
print(s1>s2)
# Out:
# True

# %%
s1>s2
# Out:
# True

# %%
s1<s2
# Out:
# False

# %%
s1==s2
# Out:
# False

# %%
s1!=s2
# Out:
# True

# %%
s1>=s2
# Out:
# True

# %%
s1<=s2
# Out:
# False

# %% [markdown]
# # 4. Logical Operators

# %% [markdown]
# ### Logical operators are used to combine conditions.
#
# | Operator | Meaning                             |
# | -------- | ----------------------------------- |
# | `and`    | Both conditions must be True        |
# | `or`     | At least one condition must be True |
# | `not`    | Reverses the result

# %% [markdown]
# # `and`

# %%
a1= 28
a2=25

# %%
a1>30 and a2<20
# Out:
# False

# %%
a1>5 and a2<20
# Out:
# False

# %%
a1>35 and a2<30
# Out:
# False

# %%
a1>25 and a2<40
# Out:
# True

# %% [markdown]
# ### `or` operator

# %%
c = 10
d = 20

# %%
c > 4 or d < 4
# Out:
# True

# %%
c > 5 or d < 5
# Out:
# True

# %%
c < 4 or d > 5
# Out:
# True

# %%
c < 20 or d > 40
# Out:
# True

# %%
c == 25 or d == 50
# Out:
# False

# %% [markdown]
# ## `not`

# %%
not(True)
# Out:
# False

# %%
not(False)
# Out:
# True

# %%
not(c == 25 or d == 50 )
# Out:
# True

# %%
not(c == 4 or d == 4)
# Out:
# True

# %% [markdown]
# ## Unary

# %%
a = 10

# %%
-(a)
# Out:
# -10

# %%
print(a)
# Out:
# 10

# %%
b = -10

# %%
-(b)
# Out:
# 10

# %%
print(b)
# Out:
# -10
