# %% [markdown]
# # Error type

# %% [markdown]
# ### 1. Syntax error

# %%
2it = 85
# Out:
#   Cell In[21], line 1
#     2it = 85
#     ^
# SyntaxError: invalid decimal literal

# %%
it = 45
IT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 it = 45
# ----> 2 IT
#
# NameError: name 'IT' is not defined

# %%
IT = 78
NIT=97

# %%
IT
# Out:
# 78

# %%
NIT
# Out:
# 97

# %% [markdown]
# ### 2.Type error

# %% [raw]
# - Type function requires at least 1 agrument or parameters

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(a)
# Out:
# int

# %%
type(R)
# Out:
# int

# %% [markdown]
# ### 3. Name error

# %% [raw]
# - User declared incorrect name

# %%
d= 45
D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 d= 45
# ----> 2 D
#
# NameError: name 'D' is not defined

# %%
my_name = "my name is shiva pandey"
My_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 my_name = "my name is shiva pandey"
# ----> 2 My_name
#
# NameError: name 'My_name' is not defined

# %%
id(R)
# Out:
# 140729276556536

# %%
age = 21
age
# Out:
# 21

# %%
print(type(age))
print(id(R))
# Out:
# <class 'int'>
# 140729276556536

# %%
a1=87
print(id(a1))
print(type(a1))
print(a1)
# Out:
# 140729276559160
# <class 'int'>
# 87

# %%
p=94
print(id(p))
print(type(p))
print(p)
# Out:
# 140729659027480
# <class 'int'>
# 94

# %% [markdown]
# # Datatype

# %% [markdown]
# ## 1. Integer

# %%
a=8
a
# Out:
# 8

# %%
R=5
R
# Out:
# 5

# %% [markdown]
# ## 2. FLOAT

# %%
t = 7.01
t
# Out:
# 7.01

# %%
type(t)
# Out:
# float

# %%
id(t)
# Out:
# 2037839434448

# %%
print(t)
print(type(t))
print(id(t))
# Out:
# 7.01
# <class 'float'>
# 2037839434448

# %%
print(t)
print(R)
print(a)
# Out:
# 7.01
# 5
# 8

# %% [markdown]
# ## 3. Boolean

# %%
v= true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 v= true
#
# NameError: name 'true' is not defined

# %%
v= True
v
# Out:
# True

# %%
type(v)
# Out:
# bool

# %%
v1=False
v1
# Out:
# False

# %%
type(v1)
# Out:
# bool

# %%
g=40
y=40

# %%
g,y=40,40

# %%
print(id(g))
print(id(y))
# Out:
# 140729276557656
# 140729276557656

# %%
print(g)
print(y)
# Out:
# 40
# 40

# %%
g=g+50
g
# Out:
# 90

# %%
print(g)
print(y)
# Out:
# 90
# 40

# %%
print(id(g))
print(id(y))
# Out:
# 140729276559256
# 140729276557656

# %%
print(v)
print(v1)
# Out:
# True
# False

# %%
v
# Out:
# True

# %%
v1
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True - False
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
True * False
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %% [markdown]
# ## 4.complex

# %%
h = 50 + 30j
h
# Out:
# (50+30j)

# %%
type(h)
# Out:
# complex

# %%
h1= 50 + 30j
h1
# Out:
# (50+30j)

# %%
h1= 50+30J # either small or capital J allowed

# %%
print(h1)
print(h)
# Out:
# (50+30j)
# (50+30j)

# %%
h
# Out:
# (50+30j)

# %%
h.real
# Out:
# 50.0

# %%
h.imag
# Out:
# 30.0

# %%
print(h)
print(h1)
# Out:
# (50+30j)
# (50+30j)

# %%
h+h1
# Out:
# (100+60j)

# %% [markdown]
# ## 5. String

# %%
s = welcome team
# Out:
#   Cell In[1], line 1
#     s = welcome team
#                 ^
# SyntaxError: invalid syntax

# %%
s= 'welcome team'
s
# Out:
# 'welcome team'

# %%
s1= "welcom team"
s1
# Out:
# 'welcom team'

# %%
s2='''welcom team'''
s2
# Out:
# 'welcom team'

# %%
s3= welcome team nareshit 
under mr prakash senapati guidence
pm batch
# Out:
#   Cell In[9], line 1
#     s3= welcome team nareshit
#                 ^
# SyntaxError: invalid syntax

# %%
s4= "welcome team nareshit 
under mr prakash senapati guidence
pm batch"
# Out:
#   Cell In[12], line 1
#     s4= "welcome team nareshit
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s5= '''welcome team nareshit 
under mr prakash senapati guidence
pm batch'''
s5
# Out:
# 'welcome team nareshit \nunder mr prakash senapati guidence\npm batch'

# %% [markdown]
# ## String indexing

# %% [markdown]
# ## Forward index

# %%
sp= 'welcome'
sp
# Out:
# 'welcome'

# %%
sp[0]
# Out:
# 'w'

# %%
sp[6]
# Out:
# 'e'

# %%
sp[2]
# Out:
# 'l'

# %%
sp[3]
# Out:
# 'c'

# %%
sp [4]
# Out:
# 'o'

# %%
sp[5]
# Out:
# 'm'

# %%
sp[7] ## index error string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sp[7] ## index error string index out of range
#
# IndexError: string index out of range

# %%
sp
# Out:
# 'welcome'

# %%
sp[10] ##index error (string index out of range)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sp[10] ##index error (string index out of range)
#
# IndexError: string index out of range

# %% [markdown]
# ## backword index

# %%
sp[-1]
# Out:
# 'e'

# %%
sp[-2]
# Out:
# 'm'

# %%
sp[-3]
# Out:
# 'o'

# %%
sp[-4]
# Out:
# 'c'

# %%
sp[-5]
# Out:
# 'l'

# %%
sp[-6]
# Out:
# 'e'

# %%
sp[-7]
# Out:
# 'w'

# %% [markdown]
# # Index slicing

# %%
ap= 'shiva pandey'
ap
# Out:
# 'shiva pandey'

# %%
ap[:]
# Out:
# 'shiva pandey'

# %% [markdown]
# ### Forward slicing

# %%
ap[6:12]
# Out:
# 'pandey'

# %%
ap[0:5]
# Out:
# 'shiva'

# %%
ap[4:6]
# Out:
# 'a '

# %%
ap[5:6]
# Out:
# ' '

# %%
ap[:6]
# Out:
# 'shiva '

# %%
ap[5:]
# Out:
# ' pandey'
