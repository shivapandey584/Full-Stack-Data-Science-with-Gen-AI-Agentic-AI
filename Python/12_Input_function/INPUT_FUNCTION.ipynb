# %% [markdown]
# # Input_function

# %%
sub = input()
# Out:
#  98

# %%
type(sub)
# Out:
# str

# %%
sub = input("enter your name")
# Out:
# enter your name shiva pandey

# %%
sub
# Out:
# 'shiva pandey'

# %%
a = input("enter a number")
b = input("enter a number")
# Out:
# enter a number 15
# enter a number 25

# %%
a,b
# Out:
# ('15', '25')

# %%
a+b
# Out:
# '1525'

# %%
sub = int(input("enter a number"))
sub1 = int(input("enter a number"))
# Out:
# enter a number 35
# enter a number 85

# %%
sub + sub1
# Out:
# 120

# %%
print(type(sub))
print(type(sub1))
# Out:
# <class 'int'>
# <class 'int'>

# %%
sub2 = input("enter a number")
sub3 = input("enter a number")
# Out:
# enter a number 15
# enter a number 35

# %%
int(sub2)
int(sub3)
# Out:
# 35

# %%
print(type(sub2))
print(type(sub3))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# # Input indexing

# %%
name = input("enter your name:")
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'shiva'

# %%
name = input("enter your name:")[0]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 's'

# %%
name = input("enter your name:")[5]
# Out:
# enter your name: shiva
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name = input("enter your name:")[5]
#
# IndexError: string index out of range

# %%
name = input("enter your name:")[4]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'a'

# %%
name = input("enter your name:")[0:]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'shiva'

# %%
name = input("enter your name:")[0:3]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'shi'

# %%
name = input("enter your name:")[::3]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'sv'

# %%
name = input("enter your name:")[::-2]
# Out:
# enter your name: shiva

# %%
name
# Out:
# 'ais'
